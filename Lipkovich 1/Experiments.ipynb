# %%
import numpy as np
import pandas as pd
np.random.seed(7)
titanic_bf = pd.read_csv('./titanic/train.csv')
print(len(titanic_bf.index))
col = np.random.randint(0, len(titanic_bf.index), 10);
titanic_bf_part = titanic_bf.iloc[col]
titanic_bf.info()
# Out:
# 891
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic_bf_part
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 175          176         0       3                  Klasen, Mr. Klas Albin
# 196          197         0       3                     Mernagh, Mr. Robert
# 537          538         1       1                     LeRoy, Miss. Bertha
# 502          503         0       3          O'Sullivan, Miss. Bridget Mary
# 579          580         1       3                     Jussila, Mr. Eiriik
# 211          212         1       2              Cameron, Miss. Clear Annie
# 615          616         1       2                     Herman, Miss. Alice
# 348          349         1       3  Coutts, Master. William Loch "William"
# 185          186         0       1                   Rood, Mr. Hugh Roscoe
# 398          399         0       2                        Pain, Dr. Alfred
#
#         Sex   Age  SibSp  Parch             Ticket      Fare Cabin Embarked
# ...

# %%
titanic_bf.groupby(['Sex', 'Pclass'])['Age', 'Fare'].mean()
# Out:
#                      Age        Fare
# Sex    Pclass
# female 1       34.611765  106.125798
#        2       28.722973   21.970121
#        3       21.750000   16.118810
# male   1       41.281386   67.226127
#        2       30.740707   19.741782
#        3       26.507589   12.661633

# %%
np.random.seed(5)
outside = "G1 G1 G1 G2 G2 G2".split()
inside =  [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
df = pd.DataFrame(np.random.randn(6,2),
                  index=hier_index,
                  columns=["A","B"])

# %%
df
# Out:
#              A         B
# G1 1  0.441227 -0.330870
#    2  2.430771 -0.252092
#    3  0.109610  1.582481
# G2 1 -0.909232 -0.591637
#    2  0.187603 -0.329870
#    3 -1.192765 -0.204877

# %%
titanic_bf_part.Age.fillna(titanic_bf.Age.mean(), inplace=True)

# %%
titanic_bf.Fare[titanic_bf.Fare > 30].hist(bins = 80)

# %%
titanic_bf.plot.scatter?
