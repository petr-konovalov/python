# %%
import pandas as pd
salaries = pd.read_csv('./salaries.csv', sep=',')

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
salaries.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
salaries[salaries.BasePay.isna()]
# Out:
#             Id           EmployeeName                        JobTitle  \
# 81391    81392        Kevin P Cashman                  Deputy Chief 3
# 84506    84507      Demetrya  Mullens       Licensed Vocational Nurse
# 84960    84961        Michael M Horan             Park Patrol Officer
# 90525    90526           Thomas  Tang                Police Officer 3
# 90786    90787         Michael C Hill                  Deputy Sheriff
# 90811    90812    Edward M Harrington     Executive Contract Employee
# 91203    91204      Spencer J Gregory                     Inspector 3
# 92260    92261            Derek  Kerr     Senior Physician Specialist
# 97418    97419         Kevin M Martin                Police Officer 3
# 98573    98574          James M Blake  Battalion Chief, Fire Suppress
# 100464  100465     Jonathon S Catlett                  Police Officer
# 101190  101191        Bunyan  Johnson   Sr District Atty Investigator
# ...

# %%
salaries.BasePay.mean()
# Out:
# 66325.44884050643

# %%
salaries.BasePay.fillna(salaries.BasePay.mean(), inplace=True)

# %%
salaries.BasePay.isna().sum()
# Out:
# 0

# %%
grouped = salaries.groupby("JobTitle")

# %%
grouped

# %%
grouped.BasePay.median().sort_values(ascending=False)
# Out:
# JobTitle
# Chief of Police                                       307450.040
# Chief, Fire Department                                302068.000
# Gen Mgr, Public Trnsp Dept                            294000.180
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)                285262.000
# Mayor                                                 281537.170
# Dep Dir for Investments, Ret                          276153.765
# Dept Head V                                           270616.270
# Adm, SFGH Medical Center                              268946.020
# Controller                                            267914.000
# EXECUTIVE CONTRACT EMPLOYEE                           264452.520
# Deputy Chief 3                                        263390.600
# Dep Chf of Dept (Fire Dept)                           260728.000
# ASSISTANT MEDICAL EXAMINER                            257510.440
# Chief Investment Officer                              257340.000
# ...

# %%
grouped.OvertimePay.max().sort_values(ascending=False)
# Out:
# JobTitle
# CAPTAIN III (POLICE DEPARTMENT)                      245131.88
# Lieutenant, Fire Suppression                         220909.48
# Deputy Sheriff                                       196689.18
# EMT/Paramedic/Firefighter                            192424.49
# Firefighter                                          160418.47
# Electronic Maintenance Tech                          146415.32
# ELECTRONIC MAINTENANCE TECHNICIAN                    139102.95
# Transit Supervisor                                   137462.80
# TRANSIT SUPERVISOR                                   135159.38
# Battalion Chief, Fire Suppress                       131217.63
# Mech Shop & Equip Supt                               125869.76
# Captain, Fire Suppression                            125868.06
# Incident Support Specialist                          125354.95
# Battlion Chief, Fire Suppressi                       124413.13
# ELECTRICAL TRANSIT SYSTEM MECHANIC                   119407.70
# ...

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
def usd_to_rub(salary):
    return salary * 63

# %%
usd_to_rub(1000)
# Out:
# 63000

# %%
salaries['BasePayRUB'] = salaries['BasePay'].apply(usd_to_rub)

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status   BasePayRUB
# ...

# %%
salaries.TotalPay.hist(bins=100)

# %%
salaries.boxplot('TotalPay')

# %%
salaries[salaries.TotalPay < 200000].TotalPay.hist(bins=100)

# %%
salaries[salaries.TotalPay < 10]
# Out:
#             Id            EmployeeName  \
# 36152    36153         MARCELLA TUCKER
# 36153    36154           ROCK CRAWFORD
# 36154    36155           SERENA HUGHES
# 36155    36156            JOE BROWN JR
# 36156    36157          PAULETTE ADAMS
# 36157    36158           KAUKAB MOHSIN
# 36158    36159      JOSEPHINE MCCREARY
# 70877    70878           Roland Baylon
# 70927    70928        Felecia Phillips
# 70928    70929         Robert Giannini
# 70932    70933              Nelly Kuan
# 70933    70934         William Mathews
# 70942    70943           Gayle Mathews
# 70956    70957            Linda Carter
# 70960    70961           Hui Qin Zhang
# 70989    70990         Georgina Pineda
# 70990    70991      Millicent Williams
# 70991    70992             Richard Lee
# 70992    70993            Audrey Sylve
# 70993    70994        Kimberly Johnson
# 70994    70995          Teddy Querubin
# 70995    70996           Joann Seabury
# 70996    70997             David Reyes
# ...

# %%
salaries[['BasePay', 'OvertimePay', 'OtherPay']].corr()
# Out:
#               BasePay  OvertimePay  OtherPay
# BasePay      1.000000     0.266633  0.283760
# OvertimePay  0.266633     1.000000  0.316592
# OtherPay     0.283760     0.316592  1.000000

# %%
salaries.plot.scatter(x='BasePay', y='OvertimePay')
